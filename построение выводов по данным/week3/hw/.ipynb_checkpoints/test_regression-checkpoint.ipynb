# %%
import statsmodels
import scipy as sc
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
from statsmodels.graphics.regressionplots import plot_leverage_resid2
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv('botswana.tsv', sep='\t')

# %%
data
# Out:
#       ceb  age  educ    religion  idlnchld  knowmeth  usemeth  evermarr  \
# 0       0   18    10    catholic       4.0       1.0      1.0         0
# 1       2   43    11  protestant       2.0       1.0      1.0         1
# 2       0   49     4      spirit       4.0       1.0      0.0         1
# 3       0   24    12       other       2.0       1.0      0.0         0
# 4       3   32    13       other       3.0       1.0      1.0         1
# ...   ...  ...   ...         ...       ...       ...      ...       ...
# 4356    0   16     7  protestant       2.0       1.0      0.0         0
# 4357    2   28     7  protestant       4.0       1.0      1.0         0
# 4358    4   24     5  protestant       4.0       1.0      1.0         0
# 4359    1   26     0      spirit       5.0       1.0      0.0         1
# 4360    6   36     3  protestant       8.0       1.0      1.0         1
#
#       agefm  heduc  urban  electric  radio   tv  bicycle
# ...

# %%
data.religion.value_counts()
# Out:
# spirit        1841
# other         1080
# protestant     993
# catholic       447
# Name: religion, dtype: int64

# %%
data.dropna()
# Out:
#       ceb  age  educ    religion  idlnchld  knowmeth  usemeth  evermarr  \
# 1       2   43    11  protestant       2.0       1.0      1.0         1
# 2       0   49     4      spirit       4.0       1.0      0.0         1
# 4       3   32    13       other       3.0       1.0      1.0         1
# 5       1   30     5      spirit       5.0       1.0      0.0         1
# 6       3   42     4       other       3.0       1.0      0.0         1
# ...   ...  ...   ...         ...       ...       ...      ...       ...
# 4353    9   49     0  protestant       5.0       0.0      0.0         1
# 4354    3   31     2  protestant       4.0       1.0      1.0         1
# 4355    4   27     6  protestant       4.0       1.0      1.0         1
# 4359    1   26     0      spirit       5.0       1.0      0.0         1
# 4360    6   36     3  protestant       8.0       1.0      1.0         1
#
#       agefm  heduc  urban  electric  radio   tv  bicycle
# ...

# %% [markdown]
# # задание 3
#
# Давайте используем этот метод для обработки пропусков в agefm и heduc.
#
# 1 Создайте признак nevermarr, равный единице там, где в agefm пропуски.
#
# 2 Удалите признак evermarr — в сумме с nevermarr он даёт константу, значит, в нашей матрице X будет мультиколлинеарность.
#
# 3 Замените NaN в признаке agefm на 0.
#
# 4 У объектов, где nevermarr = 1, замените NaN в признаке heduc на −1 (ноль использовать нельзя, так как он уже встречается у некоторых объектов выборки).
#
# Сколько осталось пропущенных значений в признаке heduc?

# %%
data.heduc.isna().sum()
# Out:
# 2405

# %%
data['nevermarr'] = data.agefm.isna().astype('int')

data.drop('evermarr', axis=1,inplace=True)

data['agefm'] = data.agefm.fillna(0)

# %%
def fill_nas_heduc(row):
    if row['nevermarr']==1 and np.isnan(row['heduc']):
         return -1
    else:
        return row['heduc']

# %%
data['heduc'] = data.apply(fill_nas_heduc, axis=1)

# %%
data
# Out:
#       ceb  age  educ    religion  idlnchld  knowmeth  usemeth  agefm  heduc  \
# 0       0   18    10    catholic       4.0       1.0      1.0    0.0   -1.0
# 1       2   43    11  protestant       2.0       1.0      1.0   20.0   14.0
# 2       0   49     4      spirit       4.0       1.0      0.0   22.0    1.0
# 3       0   24    12       other       2.0       1.0      0.0    0.0   -1.0
# 4       3   32    13       other       3.0       1.0      1.0   24.0   12.0
# ...   ...  ...   ...         ...       ...       ...      ...    ...    ...
# 4356    0   16     7  protestant       2.0       1.0      0.0    0.0   -1.0
# 4357    2   28     7  protestant       4.0       1.0      1.0    0.0   -1.0
# 4358    4   24     5  protestant       4.0       1.0      1.0    0.0   -1.0
# 4359    1   26     0      spirit       5.0       1.0      0.0   22.0    7.0
# 4360    6   36     3  protestant       8.0       1.0      1.0   21.0    0.0
#
#       urban  electric  radio   tv  bicycle  nevermarr
# ...

# %%
data.heduc.isna().sum()
# Out:
# 123

# %% [markdown]
# # 4 Избавимся от оставшихся пропусков.
#
# Для признаков idlnchld, heduc и usemeth проведите операцию, аналогичную предыдущей: создайте индикаторы пропусков по этим признакам (idlnchld_noans, heduc_noans, usemeth_noans), замените пропуски на нехарактерные значения (
#
# idlnchld =−1,
# heduc =−2 (значение -1 мы уже использовали),
# usemeth=−1).
#
# Остались только пропуски в признаках knowmeth, electric, radio, tv и bicycle. Их очень мало, так что удалите объекты, на которых их значения пропущены.
#
# Какого размера теперь наша матрица данных? Умножьте количество строк на количество всех столбцов (включая отклик ceb).

# %%
data['idlnchld_noans'] = data.idlnchld.isna().astype('int')
data['heduc_noans'] = data.heduc.isna().astype('int')
data['usemeth_noans'] = data.usemeth.isna().astype('int')

# %%
def fill_nas_var(var, val, row):
    if row[var+'_noans']==1 and np.isnan(row[var]):
         return val
    else:
        return row[var]

# %%
data['idlnchld'] = data.apply(lambda x: fill_nas_var('idlnchld', -1, x), axis=1)
data['heduc'] = data.apply(lambda x: fill_nas_var('heduc', -2, x), axis=1)
data['usemeth'] = data.apply(lambda x: fill_nas_var('usemeth', -1, x), axis=1)

# %%
data = data.dropna()
data
# Out:
#       ceb  age  educ    religion  idlnchld  knowmeth  usemeth  agefm  heduc  \
# 0       0   18    10    catholic       4.0       1.0      1.0    0.0   -1.0
# 1       2   43    11  protestant       2.0       1.0      1.0   20.0   14.0
# 2       0   49     4      spirit       4.0       1.0      0.0   22.0    1.0
# 3       0   24    12       other       2.0       1.0      0.0    0.0   -1.0
# 4       3   32    13       other       3.0       1.0      1.0   24.0   12.0
# ...   ...  ...   ...         ...       ...       ...      ...    ...    ...
# 4356    0   16     7  protestant       2.0       1.0      0.0    0.0   -1.0
# 4357    2   28     7  protestant       4.0       1.0      1.0    0.0   -1.0
# 4358    4   24     5  protestant       4.0       1.0      1.0    0.0   -1.0
# 4359    1   26     0      spirit       5.0       1.0      0.0   22.0    7.0
# 4360    6   36     3  protestant       8.0       1.0      1.0   21.0    0.0
#
# ...

# %%
data.shape
# Out:
# (4348, 18)

# %% [markdown]
# # 5
# Постройте регрессию количества детей ceb на все имеющиеся признаки методом smf.ols, как в разобранном до этого примере. Какой получился коэффициент детерминации? Округлите до трёх знаков после десятичной точки.

# %%
data.columns
# Out:
# Index(['ceb', 'age', 'educ', 'religion', 'idlnchld', 'knowmeth', 'usemeth',
#        'agefm', 'heduc', 'urban', 'electric', 'radio', 'tv', 'bicycle',
#        'nevermarr', 'idlnchld_noans', 'heduc_noans', 'usemeth_noans'],
#       dtype='object')

# %%
m1 = smf.ols('ceb ~ age + educ + religion + idlnchld + knowmeth + \
             usemeth + agefm + heduc + urban+electric+radio+tv+bicycle + \
             nevermarr+idlnchld_noans+heduc_noans+usemeth_noans', 
             data=data)
fitted = m1.fit()
print(fitted.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    ceb   R-squared:                       0.644
# Model:                            OLS   Adj. R-squared:                  0.643
# Method:                 Least Squares   F-statistic:                     412.5
# Date:                Thu, 28 Oct 2021   Prob (F-statistic):               0.00
# Time:                        23:47:42   Log-Likelihood:                -7732.1
# No. Observations:                4348   AIC:                         1.550e+04
# Df Residuals:                    4328   BIC:                         1.563e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -1.0263      0.212     -4.835      0.000      -1.443      -0.610
# ...

# %% [markdown]
# # вопрос 7
# Проверьте критерием Бройша-Пагана гомоскедастичность ошибки в построенной модели. Выполняется ли она?
#
# Если ошибка гетероскедастична, перенастройте модель, сделав поправку Уайта типа HC1.

# %%
print('Breusch-Pagan test: p=%f' % sms.het_breuschpagan(fitted.resid, fitted.model.exog)[1])
# Out:
# Breusch-Pagan test: p=0.000000

# %%
m1 = smf.ols('ceb ~ age + educ + religion + idlnchld + knowmeth + \
             usemeth + agefm + heduc + urban+electric+radio+tv+bicycle + \
             nevermarr+idlnchld_noans+heduc_noans+usemeth_noans', 
             data=data)
fitted = m1.fit(cov_type = 'HC1')
print(fitted.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    ceb   R-squared:                       0.644
# Model:                            OLS   Adj. R-squared:                  0.643
# Method:                 Least Squares   F-statistic:                     345.0
# Date:                Thu, 28 Oct 2021   Prob (F-statistic):               0.00
# Time:                        23:47:45   Log-Likelihood:                -7732.1
# No. Observations:                4348   AIC:                         1.550e+04
# Df Residuals:                    4328   BIC:                         1.563e+04
# Df Model:                          19
# Covariance Type:                  HC1
# ...
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -1.0263      0.266     -3.863      0.000      -1.547      -0.506
# ...

# %% [markdown]
# # вопрос 8
#
# Удалите из модели незначимые признаки religion, radio и tv. Проверьте гомоскедастичность ошибки, при необходимости сделайте поправку Уайта.
#
# Не произошло ли значимого ухудшения модели после удаления этой группы признаков? Проверьте с помощью критерия Фишера. Чему равен его достигаемый уровень значимости? Округлите до четырёх цифр после десятичной точки.
#
# Если достигаемый уровень значимости получился маленький, верните все удалённые признаки; если он достаточно велик, оставьте модель без религии, тв и радио.

# %%
m2 = smf.ols('ceb ~ age + educ + idlnchld + knowmeth + \
             usemeth + agefm + heduc + urban+electric + bicycle + \
             nevermarr+idlnchld_noans+heduc_noans+usemeth_noans', 
             data=data)
fitted = m2.fit()
print('Breusch-Pagan test: p=%f' % sms.het_breuschpagan(fitted.resid, fitted.model.exog)[1])
# Out:
# Breusch-Pagan test: p=0.000000

# %%
fitted = m2.fit(cov_type = 'HC1')
print(fitted.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    ceb   R-squared:                       0.644
# Model:                            OLS   Adj. R-squared:                  0.643
# Method:                 Least Squares   F-statistic:                     463.4
# Date:                Thu, 28 Oct 2021   Prob (F-statistic):               0.00
# Time:                        23:47:51   Log-Likelihood:                -7734.5
# No. Observations:                4348   AIC:                         1.550e+04
# Df Residuals:                    4333   BIC:                         1.559e+04
# Df Model:                          14
# Covariance Type:                  HC1
# ...
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         -1.0698      0.258     -4.152      0.000      -1.575      -0.565
# ...

# %%
print("F=%f, p=%f, k1=%f" % m1.fit().compare_f_test(m2.fit()))
# Out:
# F=0.919236, p=0.467231, k1=5.000000
